# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
weight = np.random.normal(loc=70, scale=5, size=500)
# height = np.random.normal(loc=170, scale=7.5, size=500)
height = (-2*weight) + 5 + np.random.normal(loc=20, scale=8, size=500)
data=pd.DataFrame(data={'Weight (Kgs)': weight, 'Height (cms)': height})

# %%
data
# Out:
#      Weight (Kgs)  Height (cms)
# 0       60.321440    185.850481
# 1       69.097306    166.192484
# 2       70.114949    171.571562
# 3       75.634499    177.803993
# 4       67.962835    163.213348
# ..            ...           ...
# 495     65.200474    168.657413
# 496     72.911591    159.417618
# 497     75.804758    160.509827
# 498     72.322723    167.117818
# 499     65.970543    170.417808
#
# [500 rows x 2 columns]

# %%
data.mean(axis=0)
# Out:
# Weight (Kgs)     69.98785
# Height (cms)    170.11219
# dtype: float64

# %%
plt.scatter(data['Weight (Kgs)'], data['Height (cms)'])
plt.xlabel('Weight (Kgs)')
plt.ylabel('Height (cms)')
plt.title('Scatter plot of Weight vs Height')
plt.show()
